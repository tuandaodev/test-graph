# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # DBLP

# %%
# !unrar x /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/data/DBLP/DBLP.rar

# %%
# !python /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/main.py --layers 3 --mode s --dataset DBLP --hidden 2 --dropout 0.1
# Out:
# /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/main.py
# Loading DBLP dataset...
# Dataset has 4057 nodes, 334 features.
# adj: <class 'scipy.sparse._csr.csr_matrix'>
# D: <class 'scipy.sparse._dia.dia_matrix'>
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/linalg/_dsolve/linsolve.py:229: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/linalg/_dsolve/linsolve.py:302: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   warn('spsolve is more efficient when sparse b '
# ...

# %% [markdown]
# # Yelp

# %%
# !unrar x /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/data/Yelp/Yelp.rar

# %%
# !python /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/main.py --layers 8 --mode r --dataset Yelp --dropout 0.1
# Out:
# /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/main.py
# Loading Yelp dataset...
# Dataset has 45954 nodes, 32 features.
# adj: <class 'scipy.sparse._csr.csr_matrix'>
# D: <class 'scipy.sparse._dia.dia_matrix'>
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/linalg/_dsolve/linsolve.py:214: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/linalg/_dsolve/linsolve.py:285: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   warn('spsolve is more efficient when sparse b '
# AdaGNN(
#   (should_train_1): Adagnn_with_weight (32 -> 128)
#   (hidden_layers): ModuleList(
#     (0-5): 6 x Adagnn_without_weight (128 -> 128)
#   )
#   (should_train_2): Adagnn_with_weight (128 -> 2)
# )
# Epoch: 0001
# loss_train: 1.5615
# acc_train: 0.2299
# auc_roc_train: 0.4997
# ...

# %% [markdown]
# # Elliptic

# %%
# !unrar x /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/data/Elliptic/Elliptic.rar

# %%
# !python /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/main.py --layers 8 --mode s --dataset Elliptic --hidden 128 --dropout 0.1
# Out:
# Streaming output truncated to the last 5000 lines.
# Model validation :
# loss_val: 0.8164
# acc_val: 0.8594
# auc_roc_val: 0.8226
# auc_pr_val: 0.6970
# time: 1.9284s
# Epoch: 0085
# Model training :
# loss_train: 0.8395
# acc_train: 0.8531
# auc_roc_train: 0.8138
# auc_pr_train: 0.6820
# Model validation :
# loss_val: 0.8161
# acc_val: 0.8594
# auc_roc_val: 0.8226
# auc_pr_val: 0.6970
# time: 1.7521s
# Epoch: 0086
# Model training :
# loss_train: 0.8365
# acc_train: 0.8564
# auc_roc_train: 0.8167
# auc_pr_train: 0.6888
# Model validation :
# loss_val: 0.8162
# acc_val: 0.8594
# auc_roc_val: 0.8226
# auc_pr_val: 0.6970
# time: 1.8882s
# Epoch: 0087
# Model training :
# loss_train: 0.8288
# acc_train: 0.8573
# auc_roc_train: 0.8190
# auc_pr_train: 0.6903
# Model validation :
# loss_val: 0.8161
# acc_val: 0.8594
# auc_roc_val: 0.8226
# auc_pr_val: 0.6970
# time: 1.8189s
# Epoch: 0088
# Model training :
# loss_train: 0.8287
# acc_train: 0.8546
# auc_roc_train: 0.8156
# ...

# %% [markdown]
# # Amazon

# %%
# !unrar x /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/data/Amazon/Amazon.rar

# %%
# !python /content/drive/MyDrive/Anomaly_detection_GNN/code/Anomaly_detection_AdaGNN/main.py --layers 8 --mode s --dataset Amazon  --dropout 0.1
